# %%
import requests
import json
import time
import numpy as np
import pandas as pd
import csv

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

api_key = 'AIzaSyC97oj_73Oab6zrUkHfWH-gq7zF2omHkOo' #You'll need your own API key: https://developers.google.com/places/web-service/get-api-key

business_types = ["fast food","beach","amusement_park","art_gallery","bakery","bar","cafe","casino","movie_theater","museum","night_club","park","restaurant","shopping_mall","spa","stadium","tourist_attraction","zoo"]


total_results = []


def get_nearby_places(coordinates, radius, business_type, next_page):
    
    i = 1
    cols=['poiId','name','latitude','longitude','preference','endereco']
    total_results = pd.DataFrame(columns=cols)
    
    #https://maps.googleapis.com/maps/api/place/textsearch/xml?query=restaurants+in+Sydney&key=
    """URL = ('https://maps.googleapis.com/maps/api/place/nearbysearch/json?location='
        +coordinates+'&radius='+radius+'&key='+ api_key +'&type='+business_type+'&pagetoken='+next_page)"""
    URL = ('https://maps.googleapis.com/maps/api/place/textsearch/json?query='+business_type+'+in+Salvador,Brasil&key='+ api_key +'&pagetoken='+next_page)
    
    r = requests.get(URL)
    response = r.text
    python_object = json.loads(response)
    results = python_object["results"]
    
    for result in results:
        place_name = result['name']
        latitude = result['geometry']['location']['lat']
        longitude = result['geometry']['location']['lng']
        types = result['types']
        endereco = result['formatted_address']

        print("{},{},{},{},{},{}".format(i,place_name, latitude, longitude, business_type, endereco))
        
        #info_temp = [i,place_name, latitude, longitude, business_type]
        info_temp = [i,place_name, latitude, longitude, business_type, endereco]
        temp = pd.DataFrame([info_temp], columns=cols)

        total_results = total_results.append(temp, ignore_index=True)
        i = i+1
    
    try:
        next_page_token = python_object["next_page_token"]
    except KeyError:
        #no next page
        return
    time.sleep(1)
    get_nearby_places(coordinates, radius, business_type, next_page_token)
    
    return total_results


for business_type in business_types:
    '''-12.9950417,-38.4959633 
    -13.0033164,-38.51906'''
    resultado = get_nearby_places('-13.0033164,-38.51906', '16093', business_type, '')
    #print(resultado)
   

    #resultado.to_csv(r'./datasets/pois/pois_google1.csv',index=False, enconding = 'utf-8')

with open('./datasets/pois/employee_file.csv', mode='w') as resultado:
    employee_writer = csv.writer(resultado, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

    employee_writer.writerow()
# Out:
# 1,Giraffas,-12.9137397,-38.3344951,fast food,Salvador International Airport - Deputado Luís Eduardo Magalhães - Praça Gago Coutinho, S/N - São Cristóvão, Salvador - BA, 41510-045, Brazil
# 2,Bob's Shakes,-12.9137223,-38.3357009,fast food,Praça Gago Coutinho, S/N - São Cristóvão, Salvador - BA, 41510-055, Brazil
# 3,McDonald's,-13.0125729,-38.4834309,fast food,Rua Oswaldo Cruz, s/n - Rio Vermelho, Salvador - BA, 41940-000, Brazil
# 4,Subway,-12.9392897,-38.3422141,fast food,Alameda Dilson Jatahy Fonseca, 601 - Stella Maris, Salvador - BA, 41600-100, Brazil
# 5,Tabuleiro,-12.9137008,-38.3348494,fast food,Aeroporto Internacional de Salvador, Praça Gago Coutinho - Dep. Luís Eduardo Magalhães, 3003 - São Cristóvão, Salvador - BA, 41510-055, Brazil
# 6,Burger King,-12.9856598,-38.4663217,fast food,Av. Antônio Carlos Magalhães, S/N - Parque Bela Vista, Salvador - BA, 41800-700, Brazil
# ...
